# %%
#https://github.com/alexarnimueller/som
import pandas as pd
import numpy as np
df = pd.read_csv('winequality-red.csv', sep = ';')

arr = np.asarray(df)
data = arr
targets = arr[:,-1]
targets = targets.astype(int)
print(df.columns)
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
from som import SOM

# initialize the SOM
som = SOM(5, 5)

# fit the SOM for 20000 epochs, save the error every 300 steps
som.fit(data, 20000, save_e=True, interval=300)
# Out:
# Epoch 0;    Neuron [0, 2];    	Sigma: 2.5000;    alpha: 0.6000
# Epoch 1;    Neuron [0, 0];    	Sigma: 2.5000;    alpha: 0.6000
# Epoch 2;    Neuron [0, 2];    	Sigma: 2.5000;    alpha: 0.6000
# Epoch 3;    Neuron [0, 2];    	Sigma: 2.5000;    alpha: 0.6000
# Epoch 4;    Neuron [0, 0];    	Sigma: 2.5000;    alpha: 0.6000
# Epoch 5;    Neuron [4, 0];    	Sigma: 2.5000;    alpha: 0.6000
# Epoch 6;    Neuron [0, 3];    	Sigma: 2.5000;    alpha: 0.6000
# Epoch 7;    Neuron [0, 3];    	Sigma: 2.5000;    alpha: 0.6000
# Epoch 8;    Neuron [2, 2];    	Sigma: 2.5000;    alpha: 0.6000
# Epoch 9;    Neuron [2, 0];    	Sigma: 2.5000;    alpha: 0.6000
# Epoch 10;    Neuron [2, 0];    	Sigma: 2.5000;    alpha: 0.6000
# Epoch 11;    Neuron [0, 3];    	Sigma: 2.5000;    alpha: 0.6000
# Epoch 12;    Neuron [3, 0];    	Sigma: 2.5000;    alpha: 0.6000
# Epoch 13;    Neuron [2, 0];    	Sigma: 2.5000;    alpha: 0.6000
# Epoch 14;    Neuron [1, 4];    	Sigma: 2.5000;    alpha: 0.6000
# ...

# %%
# plot the training error history
som.plot_error_history()

# %%
print(np.unique(targets))
colors = ['yellow', 'blue','green','#391010','white','#1B879C','red','orange','cyan']
som.plot_point_map(data=data,
                   targets=targets,
                   targetnames=np.arange(0, np.max(targets)+1),
                   colors = colors
                   )
# Out:
# D:\soft\Anaconda3\lib\site-packages\matplotlib\text.py:1150: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
som.plot_distance_map()
